# %% [markdown]
# # Problem2: Optimal Bayesian Estimation

# %% [markdown]
# # 0- First Some Data Pre-Processing
#
# - At this moment you should have "train_PCA.pkl" and "test_PCA.pkl" files in your working directory

# %%
# %matplotlib inline

import matplotlib
import pickle
import numpy as np
import math
from scipy.stats import multivariate_normal
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.covariance import MinCovDet
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

train_data=pickle.load(open("train_PCA.pkl", "rb" ))
test_data=pickle.load(open("test_PCA.pkl", "rb" ))

# %%
def scatter_plot(predicted):
    
    t0 = np.take(train_feature, np.where(predicted == 0)[0], axis=0)
    
    t1 = np.take(train_feature, np.where(predicted == 1)[0], axis=0)
    
    t2 = np.take(train_feature, np.where(predicted == 2)[0], axis=0)
    
    t3 = np.take(train_feature, np.where(predicted == 3)[0], axis=0)
    
    pca = PCA(n_components=2)
    
    t0_pca = pca.fit(t0).transform(matrix_data_0).transpose()
    plt.scatter(t0_pca[0], t0_pca[1], label="0")
    
    t1_pca = pca.fit(t1).transform(matrix_data_1).transpose()
    plt.scatter(t1_pca[0], t1_pca[1], label="1")
    
    t2_pca = pca.fit(t2).transform(matrix_data_2).transpose()
    plt.scatter(t2_pca[0], t2_pca[1], label="2")
    
    t3_pca = pca.fit(t3).transform(matrix_data_3).transpose()
    plt.scatter(t3_pca[0], t3_pca[1], label="3")
    
    
def roc_plot(t, p):
    
    test_vectorized = label_binarize(t, classes=[0,1,2,3])
    y =  label_binarize(p, classes=[0,1,2,3])
    
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    for i in range(4):
        fpr[i], tpr[i], _ = roc_curve(test_vectorized[:,i],y[:,i]) # i column # pos_label=i
        roc_auc[i] = auc(fpr[i], tpr[i])
        
    lw = 2
    for i in range(4):
        plt.figure()
        plt.plot(fpr[i], tpr[i], color='green',
             lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[i])
        plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver operating characteristic example_group'+str(i))
        plt.legend(loc="lower right")
        filename="ROC_"+str(i)+".png"
        plt.savefig(filename)

# %%
categories = ['alt.atheism',
              'talk.religion.misc',
              'comp.graphics',
              'sci.space']

num_classes = len(categories)

# %%
val_ratio  = 0.1 
e=math.e
L = [e**-25, e**-20, e**-15, e**-10, e**-5,0,1,2,3, e**5, e**10] # range of lambda

# %%
#Split Train data into Train and Validation (Ratio Train : Val = 4:1)

train_num = int(train_data['data'].shape[0]*(1.0-val_ratio)) 
val_num = -1*int(train_data['data'].shape[0]*val_ratio)

# %%
#Train data and Train Target
#Validation data and Validation Target

train_feature = train_data['data'][:train_num]
train_target = train_data['target'][:train_num]

val_feature = train_data['data'][val_num:]
val_target = train_data['target'][val_num:]

test_feature = test_data['data']
test_target = test_data['target']
test_num = test_data['data'].shape[0]

# %%
# shape of data set

print(train_feature.shape)
print(val_feature.shape)
print(test_num)
# Out:
# (1830, 1500)
# (203, 1500)
# 1353

# %% [markdown]
# # 1- Find Mean and Prior for Estimating Multivariate Normal Dist. for Classes

# %%
from __future__ import division
# Find the mean and prior (which is just the frequency)
mu = np.zeros((len(categories), train_feature.shape[1]), dtype=float)
Pi = np.zeros(len(categories),dtype=float)

num_features = train_feature.shape[1]

unique, Pi = np.unique(train_target, return_counts=True)

matrix_data_0 = np.take(train_feature, np.where(train_target == 0)[0], axis=0)
np.mean(matrix_data_0, axis=0, out=mu[0])

matrix_data_1 = np.take(train_feature, np.where(train_target == 1)[0], axis=0)
np.mean(matrix_data_1, axis=0, out=mu[1])

matrix_data_2 = np.take(train_feature, np.where(train_target == 2)[0], axis=0)
np.mean(matrix_data_2, axis=0, out=mu[2])

matrix_data_3 = np.take(train_feature, np.where(train_target == 3)[0], axis=0)
np.mean(matrix_data_3, axis=0, out=mu[3])

Pi = np.log(Pi/train_num)

# %% [markdown]
# # 2- Build Models For Several Cases
#
# For each case consider the followings:
#
#
# - First, compute the covariance matrix (name it cov)
#
# - Build the Multivariate Normal dist. based on the computed mean and cov.
#
# - Then build the Model
#
# - Report the Confusion Matrix, ROC and plot the data scatter and the decision boundaries in 2D (so based on top-2 PCA features). For the Confusion matrix and ROC, use Scilearn built in functions.

# %% [markdown]
#  *Case 0: multivariate normals with shared spherical variances:*
#
# - In this case, first compute the cov to be a diagonal matrix with the same element on diag which is the average of the feasure variances, i.e. sum(diag(cov(x)))/2*eye(2), x is the data point matrix.

# %%
#In this case, we  keep the average variance along the diagonal of the covariance matrix of the entire data.
#This results in very gaussians withd ifferent means but same variances. The constant probability curve
#for each class are axis-parallel hyperspheres.

cov = (np.sum(np.diag(np.cov(train_feature, rowvar=False)))/num_features) * np.eye(num_features)

post_yx = np.zeros((4, test_num), dtype=float)

post_yx[0] = multivariate_normal(mean=mu[0], cov=cov).logpdf(test_feature) + Pi[0]
post_yx[1] = multivariate_normal(mean=mu[1], cov=cov).logpdf(test_feature) + Pi[1]
post_yx[2] = multivariate_normal(mean=mu[2], cov=cov).logpdf(test_feature) + Pi[2]
post_yx[3] = multivariate_normal(mean=mu[3], cov=cov).logpdf(test_feature) + Pi[3]

temp = np.sum(post_yx, axis=0)

prediction_case_0 = post_yx.argmax(axis=0)

conf_mat_case_0 = confusion_matrix(test_target, prediction_case_0)

test_accuracy_case_0 = accuracy_score(test_target, prediction_case_0)
print(conf_mat_case_0)
print(test_accuracy_case_0)

scatter_plot(prediction_case_0)
roc_plot(test_target, prediction_case_0)
# Out:
# [[219  26   6  68]
#  [  1 377   8   3]
#  [  1  28 363   2]
#  [ 28  21   7 195]]
# 0.8529194382852919

# %% [markdown]
# *Case 1: multivariate normals with shared axis parellel variances:*
#
# - In this case, first compute the cov to be the diagonal matrix with the variance of each feasure on the diag, i.e. diag(diag(cov(x))).

# %%
#In this case, we only keep the diagonal elements of the covariance matrix. This results in gaussians with
#different means but shared variance and constant probability regions are axis parallel hyperellipses


cov = np.diag(np.diag(np.cov(train_feature, rowvar=False)))

post_yx[0] = multivariate_normal(mean=mu[0], cov=cov).logpdf(test_feature) + Pi[0]
post_yx[1] = multivariate_normal(mean=mu[1], cov=cov).logpdf(test_feature) + Pi[1]
post_yx[2] = multivariate_normal(mean=mu[2], cov=cov).logpdf(test_feature) + Pi[2]
post_yx[3] = multivariate_normal(mean=mu[3], cov=cov).logpdf(test_feature) + Pi[3]

prediction_case_1 = post_yx.argmax(axis=0)

conf_mat_case_1 = confusion_matrix(test_target, prediction_case_1)

test_accuracy_case_1 = accuracy_score(test_target, prediction_case_1)
print("Confusion Matrix :\n", conf_mat_case_1)
print("Test Accuracy : ", test_accuracy_case_1)

scatter_plot(prediction_case_1)
roc_plot(test_target, prediction_case_1)
# Out:
# ('Confusion Matrix :\n', array([[255,  12,  15,  37],
#        [  0, 382,   6,   1],
#        [  1,  25, 368,   0],
#        [ 33,  23,  17, 178]]))
# ('Test Accuracy : ', 0.8743532889874354)

# %% [markdown]
# *Case 2: multivariate normals with shared arbitrary variances:*
#
# - In this case, first compute cov to be the general covariance matrix of feasures, i.e. cov(x).

# %%
#In this case, we  keep the entire covariance matrix. This results in very general gaussians with
#different means and shared variance where constant probability regions are non-axis-parallel hyperellipses


cov = np.cov(train_feature, rowvar=False)

post_yx[0] = multivariate_normal(mean=mu[0], cov=cov).logpdf(test_feature) + Pi[0]
post_yx[1] = multivariate_normal(mean=mu[1], cov=cov).logpdf(test_feature) + Pi[1]
post_yx[2] = multivariate_normal(mean=mu[2], cov=cov).logpdf(test_feature) + Pi[2]
post_yx[3] = multivariate_normal(mean=mu[3], cov=cov).logpdf(test_feature) + Pi[3]

prediction_case_2 = post_yx.argmax(axis=0)

conf_mat_case_2 = confusion_matrix(test_target, prediction_case_2)

test_accuracy_case_2 = accuracy_score(test_target, prediction_case_2)
print("Confusion Matrix :\n", conf_mat_case_2)
print("Test Accuracy : ", test_accuracy_case_2)

scatter_plot(prediction_case_2)
roc_plot(test_target, prediction_case_2)
# Out:
# ('Confusion Matrix :\n', array([[254,  17,  10,  38],
#        [  1, 378,   9,   1],
#        [  4,  25, 365,   0],
#        [ 32,  20,  13, 186]]))
# ('Test Accuracy : ', 0.8743532889874354)

# %% [markdown]
# *Case 3: multivariate normals with shared spherical variances:*
#
# - In this case, first compute a cov for each class.

# %%
#In this case, we  keep the entire covariance matrix. This results in very general gaussians with
#different means and different variances. The constant probability curve  for each class are axis-parallel
#hyperspheres


cov0 = (np.sum(np.diag(np.cov(matrix_data_0, rowvar=False)))/num_features) * np.eye(num_features)
cov1 = (np.sum(np.diag(np.cov(matrix_data_1, rowvar=False)))/num_features) * np.eye(num_features)
cov2 = (np.sum(np.diag(np.cov(matrix_data_2, rowvar=False)))/num_features) * np.eye(num_features)
cov3 = (np.sum(np.diag(np.cov(matrix_data_3, rowvar=False)))/num_features) * np.eye(num_features)

post_yx[0] = multivariate_normal(mean=mu[0], cov=cov0).logpdf(test_feature) + Pi[0]
post_yx[1] = multivariate_normal(mean=mu[1], cov=cov1).logpdf(test_feature) + Pi[1]
post_yx[2] = multivariate_normal(mean=mu[2], cov=cov2).logpdf(test_feature) + Pi[2]
post_yx[3] = multivariate_normal(mean=mu[3], cov=cov3).logpdf(test_feature) + Pi[3]

prediction_case_3 = post_yx.argmax(axis=0)

conf_mat_case_3 = confusion_matrix(test_target, prediction_case_3)

test_accuracy_case_3 = accuracy_score(test_target, prediction_case_3)
print("Confusion Matrix :\n", conf_mat_case_3)
print("Test Accuracy : ", test_accuracy_case_3)

scatter_plot(prediction_case_3)
roc_plot(test_target, prediction_case_3)
# Out:
# ('Confusion Matrix :\n', array([[289,   0,  15,  15],
#        [ 16, 268, 104,   1],
#        [  4,   2, 388,   0],
#        [ 84,   0,  27, 140]]))
# ('Test Accuracy : ', 0.8019216555801921)

# %% [markdown]
# Case 4: Same as case 3, but with reject option. Threshold 0.3

# %%
#In this case, we  keep the entire covariance matrix. This results in very general gaussians with
#different means and different variances. The constant probability curve for each class are axis-parallel
#hyperspheres. I have taken the reject-threshold to be 0.1.


from sklearn import metrics

reject_threshold = 0.1

def reject_outlier(a):
    return np.argmax(a) if np.max(a) > reject_threshold else 4

cov0 = (np.sum(np.diag(np.cov(matrix_data_0, rowvar=False)))/num_features) * np.eye(num_features)
cov1 = (np.sum(np.diag(np.cov(matrix_data_1, rowvar=False)))/num_features) * np.eye(num_features)
cov2 = (np.sum(np.diag(np.cov(matrix_data_2, rowvar=False)))/num_features) * np.eye(num_features)
cov3 = (np.sum(np.diag(np.cov(matrix_data_3, rowvar=False)))/num_features) * np.eye(num_features)

post_yx[0] = multivariate_normal(mean=mu[0], cov=cov0).logpdf(test_feature) + Pi[0]
post_yx[1] = multivariate_normal(mean=mu[1], cov=cov1).logpdf(test_feature) + Pi[1]
post_yx[2] = multivariate_normal(mean=mu[2], cov=cov2).logpdf(test_feature) + Pi[2]
post_yx[3] = multivariate_normal(mean=mu[3], cov=cov3).logpdf(test_feature) + Pi[3]

post_yx = post_yx / np.sum(post_yx, axis=0)

prediction_case_4 = np.apply_along_axis(reject_outlier, 0, post_yx)

conf_mat_case_4 = confusion_matrix(test_target, prediction_case_4)

test_accuracy_case_4 = accuracy_score(test_target, prediction_case_4)
print("Confusion Matrix :\n", conf_mat_case_4)
print("Test Accuracy : ", test_accuracy_case_4)

scatter_plot(prediction_case_4)
roc_plot(test_target, prediction_case_4)
# Out:
# ('Confusion Matrix :\n', array([[289,   0,  15,  15],
#        [ 16, 268, 104,   1],
#        [  4,   2, 388,   0],
#        [ 84,   0,  27, 140]]))
# ('Test Accuracy : ', 0.8019216555801921)
